# %%
# !pip install pyfpgrowth
# Out:
# Requirement already satisfied: pyfpgrowth in c:\users\abhij\anaconda3\lib\site-packages (1.0)

# %% [markdown]
# # Find frequent QA combinations that correlate to Outcome

# %%
import numpy as np
import pandas as pd
import pyfpgrowth
import itertools

# %% [markdown]
# ## Load pivoted data

# %%
data = pd.read_csv('survey_data.csv')

# %% [markdown]
# Filter out NaN outcomes. They don't support your further analyses here.

# %%
data = data.loc[~data.outcome.isna()]

# %% [markdown]
# ## Create lists to store outcomes

# %%
risks = list(set(itertools.chain.from_iterable(data['outcome'].str.split('|'))))
risks
# Out:
# ['Gender equality',
#  'Economic stability',
#  'Displacement & migration',
#  'Internal security',
#  'Justice & rule of law',
#  'Environment & climate',
#  'Social cohesion, equality & non-discrimination',
#  'Public health',
#  'Regional & global influences',
#  'Food security, agriculture & land',
#  'Infrastructure & access to social services',
#  'All of the above',
#  'Democratic space',
#  'Political stability']

# %% [markdown]
# Convert outcomes to list and then replace "All of the above" with a list of all risk factors.

# %%
data['outcome'] = data['outcome'].str.split('|').apply(lambda x: set(risks).intersection(set(x)))
data['outcome'] = data['outcome'].apply(lambda x: set([x for x in risks if x!='All of the above']) if "All of the above" in x else x)

# %% [markdown]
# ## Map question answers to ordinal scale

# %%
cols = list(data.columns[4:])

def rep(x):
    
    ### Possible answers to standardize
    # identity and demographics - drop column
    # national/UN coping capacity - very high, high, moderate, low, none, don't know
    # risk increase potential - yes: very strong, yes: strong, yes: moderate, yes: minor, no, don't know
    
    if x is np.nan:
        return "Missing"
    
    x = x.lower()
    
    if ('very' in x) and ('high' in x or 'strong' in x):
        return "Very high"
    
    if ('high' in x or 'strong' in x):
        return "High"
    
    if ('moderate' in x):
        return "Moderate"
    
    if ('low' in x or 'minor' in x):
        return "Minor"
    
    if ("no" in x):
        return "No"
    
    if ("none" in x):
        return "None"
    
    if ("don't" in x):
        return "Don't Know"
    

for c in cols:
    # treat q143 separately
    if 'q143' in c:
        continue
    
    # drop q170
    if 'q170' in c:
        del data[c]
        continue
    
    data[c] = data[c].apply(rep)

# %% [markdown]
# ## Explode the Outcome column (which is an iterable) to separate rows

# %%
data = data.explode('outcome', ignore_index=True)

# %% [markdown]
# Remove identifier columns and prepare data for FP-Growth.

# %%
data_fp = data.drop(['Country','Survey_ID','Participant_ID'], axis=1).copy()
data_fp.shape
# Out:
# (3527, 41)

# %% [markdown]
# ## Necessary step for pre-pending question id to answers.

# %% [markdown]
# If you remove this step, it will result in erroneous item sets in the pattern mining algorithm.

# %%
for col in data_fp.columns:
    if col not in ['outcome','q143']:
        data_fp[col] = col + '=' + data_fp[col]

# %% [markdown]
# ## Select questions with low % missing values

# %%
table = data_fp[['outcome','q109','q111','q112','q114','q115','q117','q118','q132','q133','q135','q136','q138','q139','q141','q143','q3','q7']]

# %% [markdown]
# ## Find frequent patterns

# %% [markdown]
# Threshold will depend on the number of rows in table from previous cell. Ensure sufficient data. If your support is too high, you will not find any patterns because the data is super-sparse with high number of missing values.

# %%
thresh = 0.05

# %%
patterns = pyfpgrowth.find_frequent_patterns(table.to_numpy(), thresh*table.shape[0])

# %%
patterns
# Out:
# {('q136=Very high',): 187,
#  ('Public health',): 189,
#  ('Internal security',): 205,
#  ('Regional & global influences',): 217,
#  ('q115=Moderate',): 251,
#  ('q109=Very high',): 254,
#  ('Displacement & migration', 'q112=Missing'): 184,
#  ('Displacement & migration', 'q115=Missing'): 200,
#  ('q115=Very high', 'q117=Minor'): 178,
#  ('q112=Missing', 'q115=Very high'): 187,
#  ('q115=Very high', 'q135=Minor'): 206,
#  ('1: No', 'q135=Missing'): 186,
#  ('1: No', 'q115=Missing', 'q135=Missing'): 180,
#  ('1: No', 'q115=Missing'): 198,
#  ('1: No', 'q112=Missing'): 208,
#  ('1: No', 'q112=Missing', 'q138=Missing'): 194,
#  ('1: No', 'q136=Missing'): 210,
#  ('1: No', 'q114=Missing', 'q136=Missing'): 206,
#  ('1: No', 'q138=Missing'): 210,
#  ('1: No', 'q114=Missing'): 224,
#  ('q118=Very high', 'q135=Missing'): 178,
#  ('q115=Missing', 'q118=Very high', 'q135=Missing'): 178,
#  ('q118=Very high', 'q139=Very high'): 179,
#  ('q114=Missing', 'q118=Very high'): 186,
#  ('q115=Missing', 'q118=Very high'): 191,
#  ('q118=Very high', 'q132=Minor'): 193,
#  ('q118=Very high', 'q138=Missing'): 198,
#  ('q112=Missing', 'q118=Very high', 'q138=Missing'): 187,
#  ('q112=Missing', 'q118=Very high'): 200,
#  ('q112=High',): 320,
#  ('q112=High', 'q115=Missing'): 196,
#  ('Justice & rule of law', 'q133=Missing'): 210,
#  ('Justice & rule of law', 'q117=Missing', 'q133=Missing'): 210,
#  ('Justice & rule of law', 'q133=Missing', 'q135=Missing'): 191,
#  ('Justice & rule of law', 'q115=Missing', 'q133=Missing'): 191,
#  ('Justice & rule of law',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 191,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing'): 191,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q133=Missing',
#   'q135=Missing'): 191,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 191,
#  ('Justice & rule of law', 'q114=Missing', 'q117=Missing'): 186,
#  ('Justice & rule of law', 'q117=Missing', 'q138=Missing'): 188,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q117=Missing',
#   'q138=Missing'): 177,
#  ('Justice & rule of law', 'q117=Missing', 'q135=Missing'): 193,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q117=Missing',
#   'q135=Missing'): 193,
#  ('Justice & rule of law', 'q112=Missing', 'q117=Missing'): 194,
#  ('Justice & rule of law', 'q115=Missing', 'q117=Missing'): 214,
#  ('Justice & rule of law',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing'): 200,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 200,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 205,
#  ('Justice & rule of law', 'q112=Missing', 'q136=Missing'): 210,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing'): 178,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q136=Missing',
#   'q138=Missing'): 210,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing'): 210,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 178,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 210,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 188,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 181,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 208,
#  ('Justice & rule of law', 'q136=Missing', 'q138=Missing'): 220,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 213,
#  ('Justice & rule of law', 'q114=Missing', 'q136=Missing'): 250,
#  ('Justice & rule of law', 'q114=Missing', 'q135=Missing'): 209,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 209,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing'): 179,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 179,
#  ('Justice & rule of law',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 184,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 181,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q138=Missing'): 213,
#  ('Justice & rule of law', 'q114=Missing', 'q115=Missing'): 228,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing'): 198,
#  ('Justice & rule of law', 'q112=Missing', 'q114=Missing'): 230,
#  ('Justice & rule of law', 'q112=Missing', 'q135=Missing'): 217,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q135=Missing',
#   'q138=Missing'): 211,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing'): 217,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 211,
#  ('Justice & rule of law', 'q135=Missing', 'q138=Missing'): 220,
#  ('Justice & rule of law',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 220,
#  ('Justice & rule of law', 'q115=Missing', 'q135=Missing'): 275,
#  ('Justice & rule of law', 'q115=Missing', 'q138=Missing'): 230,
#  ('Justice & rule of law',
#   'q112=Missing',
#   'q115=Missing',
#   'q138=Missing'): 219,
#  ('Justice & rule of law', 'q112=Missing', 'q138=Missing'): 265,
#  ('Justice & rule of law', 'q112=Missing'): 282,
#  ('Justice & rule of law', 'q112=Missing', 'q115=Missing'): 236,
#  ('Justice & rule of law', 'q115=Missing'): 296,
#  ('2: Minor change, not urgent', 'q139=Missing'): 192,
#  ('2: Minor change, not urgent', 'q111=Missing'): 198,
#  ('2: Minor change, not urgent', 'q117=Missing'): 218,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q117=Missing'): 190,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q118=Missing'): 179,
#  ('2: Minor change, not urgent', 'q118=Missing', 'q132=Missing'): 196,
#  ('2: Minor change, not urgent', 'q114=Missing', 'q132=Missing'): 177,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q132=Missing'): 202,
#  ('2: Minor change, not urgent',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing'): 177,
#  ('2: Minor change, not urgent',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 179,
#  ('2: Minor change, not urgent', 'q112=Missing', 'q136=Missing'): 187,
#  ('2: Minor change, not urgent',
#   'q112=Missing',
#   'q136=Missing',
#   'q138=Missing'): 187,
#  ('2: Minor change, not urgent',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing'): 187,
#  ('2: Minor change, not urgent',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 187,
#  ('2: Minor change, not urgent', 'q136=Missing', 'q138=Missing'): 206,
#  ('2: Minor change, not urgent',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 192,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q136=Missing'): 216,
#  ('2: Minor change, not urgent',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 202,
#  ('2: Minor change, not urgent', 'q114=Missing', 'q136=Missing'): 234,
#  ('2: Minor change, not urgent', 'q109=Missing', 'q115=Missing'): 181,
#  ('2: Minor change, not urgent', 'q109=Missing', 'q138=Missing'): 182,
#  ('2: Minor change, not urgent', 'q109=Missing', 'q141=Missing'): 224,
#  ('2: Minor change, not urgent', 'q114=Missing', 'q135=Missing'): 192,
#  ('2: Minor change, not urgent',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 189,
#  ('2: Minor change, not urgent', 'q114=Missing', 'q138=Missing'): 204,
#  ('2: Minor change, not urgent',
#   'q112=Missing',
#   'q114=Missing',
#   'q138=Missing'): 193,
#  ('2: Minor change, not urgent', 'q112=Missing', 'q114=Missing'): 207,
#  ('2: Minor change, not urgent', 'q114=Missing', 'q115=Missing'): 228,
#  ('2: Minor change, not urgent', 'q112=Missing', 'q115=Missing'): 209,
#  ('2: Minor change, not urgent',
#   'q112=Missing',
#   'q115=Missing',
#   'q138=Missing'): 195,
#  ('2: Minor change, not urgent', 'q112=Missing', 'q138=Missing'): 251,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q141=Missing'): 189,
#  ('2: Minor change, not urgent', 'q138=Missing', 'q141=Missing'): 191,
#  ('2: Minor change, not urgent', 'q135=Missing', 'q138=Missing'): 180,
#  ('2: Minor change, not urgent',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 177,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q135=Missing'): 268,
#  ('2: Minor change, not urgent', 'q138=Missing'): 284,
#  ('2: Minor change, not urgent', 'q115=Missing', 'q138=Missing'): 220,
#  ('2: Minor change, not urgent', 'q115=Missing'): 316,
#  ('Social cohesion, equality & non-discrimination', 'q118=Missing'): 179,
#  ('Social cohesion, equality & non-discrimination', 'q132=Missing'): 196,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q133=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q133=Missing',
#   'q135=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q133=Missing',
#   'q135=Missing'): 191,
#  ('Social cohesion, equality & non-discrimination',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q117=Missing',
#   'q133=Missing'): 208,
#  ('Social cohesion, equality & non-discrimination',
#   'q117=Missing',
#   'q136=Missing'): 183,
#  ('Social cohesion, equality & non-discrimination',
#   'q117=Missing',
#   'q138=Missing'): 186,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q117=Missing'): 187,
#  ('Social cohesion, equality & non-discrimination',
#   'q117=Missing',
#   'q135=Missing'): 191,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q117=Missing',
#   'q135=Missing'): 191,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q117=Missing'): 192,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q117=Missing'): 227,
#  ('Social cohesion, equality & non-discrimination',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 178,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing'): 205,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 205,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 211,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q136=Missing'): 221,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing'): 186,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q136=Missing',
#   'q138=Missing'): 221,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing'): 221,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 186,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 186,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 221,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 186,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 198,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 187,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 220,
#  ('Social cohesion, equality & non-discrimination',
#   'q136=Missing',
#   'q138=Missing'): 233,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 222,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q136=Missing'): 266,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing'): 180,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 179,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q135=Missing',
#   'q138=Missing'): 207,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 207,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing'): 212,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q135=Missing'): 215,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 214,
#  ('Social cohesion, equality & non-discrimination',
#   'q135=Missing',
#   'q138=Missing'): 216,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 216,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q135=Missing'): 278,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 190,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 189,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q138=Missing'): 224,
#  ('Social cohesion, equality & non-discrimination',
#   'q115=Missing',
#   'q138=Missing'): 236,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing',
#   'q138=Missing'): 222,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q138=Missing'): 271,
#  ('Social cohesion, equality & non-discrimination',
#   'q114=Missing',
#   'q115=Missing'): 240,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing'): 205,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q114=Missing'): 244,
#  ('Social cohesion, equality & non-discrimination', 'q112=Missing'): 291,
#  ('Social cohesion, equality & non-discrimination',
#   'q112=Missing',
#   'q115=Missing'): 238,
#  ('Social cohesion, equality & non-discrimination', 'q115=Missing'): 314,
#  ('Economic stability', 'q139=Missing'): 185,
#  ('Economic stability', 'q111=Missing'): 199,
#  ('Economic stability', 'q135=Missing'): 214,
#  ('Economic stability', 'q115=Missing', 'q135=Missing'): 212,
#  ('Economic stability', 'q141=Missing'): 233,
#  ('Economic stability', 'q109=Missing', 'q141=Missing'): 209,
#  ('Economic stability', 'q109=Missing'): 235,
#  ('Economic stability', 'q109=Missing', 'q138=Missing'): 179,
#  ('Economic stability', 'q132=Missing', 'q136=Missing'): 180,
#  ('Economic stability', 'q112=Missing', 'q132=Missing', 'q138=Missing'): 178,
#  ('Economic stability', 'q118=Missing', 'q132=Missing', 'q138=Missing'): 180,
#  ('Economic stability', 'q114=Missing', 'q132=Missing'): 193,
#  ('Economic stability', 'q112=Missing', 'q132=Missing'): 195,
#  ('Economic stability', 'q115=Missing', 'q132=Missing'): 197,
#  ('Economic stability', 'q118=Missing', 'q132=Missing'): 236,
#  ('Economic stability', 'q118=Missing', 'q136=Missing'): 189,
#  ('Economic stability', 'q114=Missing', 'q118=Missing', 'q136=Missing'): 177,
#  ('Economic stability', 'q114=Missing', 'q118=Missing'): 193,
#  ('Economic stability', 'q112=Missing', 'q118=Missing'): 194,
#  ('Economic stability', 'q112=Missing', 'q118=Missing', 'q138=Missing'): 181,
#  ('Economic stability', 'q115=Missing', 'q118=Missing'): 196,
#  ('Economic stability', 'q118=Missing', 'q138=Missing'): 199,
#  ('Economic stability', 'q115=Missing', 'q136=Missing', 'q138=Missing'): 188,
#  ('Economic stability', 'q114=Missing', 'q115=Missing', 'q136=Missing'): 203,
#  ('Economic stability', 'q112=Missing', 'q136=Missing'): 221,
#  ('Economic stability', 'q112=Missing', 'q136=Missing', 'q138=Missing'): 221,
#  ('Economic stability', 'q112=Missing', 'q114=Missing', 'q136=Missing'): 221,
#  ('Economic stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 221,
#  ('Economic stability', 'q136=Missing', 'q138=Missing'): 241,
#  ('Economic stability', 'q114=Missing', 'q136=Missing', 'q138=Missing'): 228,
#  ('Economic stability', 'q114=Missing', 'q136=Missing'): 272,
#  ('Economic stability', 'q114=Missing', 'q115=Missing', 'q138=Missing'): 179,
#  ('Economic stability', 'q112=Missing', 'q115=Missing', 'q138=Missing'): 205,
#  ('Economic stability', 'q112=Missing', 'q115=Missing'): 225,
#  ('Economic stability', 'q112=Missing', 'q114=Missing', 'q115=Missing'): 194,
#  ('Economic stability', 'q114=Missing', 'q115=Missing'): 227,
#  ('Economic stability', 'q114=Missing', 'q138=Missing'): 232,
#  ('Economic stability', 'q112=Missing', 'q114=Missing', 'q138=Missing'): 225,
#  ('Economic stability', 'q112=Missing', 'q114=Missing'): 249,
#  ('Economic stability', 'q138=Missing'): 301,
#  ('Economic stability', 'q112=Missing', 'q138=Missing'): 281,
#  ('Economic stability', 'q112=Missing'): 305,
#  ('q133=Missing', 'q139=Very high'): 178,
#  ('q117=Missing', 'q133=Missing', 'q139=Very high'): 178,
#  ('5: Significant change, immediately', 'q139=Very high'): 199,
#  ('q114=Missing', 'q117=Missing', 'q139=Very high'): 177,
#  ('q115=Missing', 'q117=Missing', 'q139=Very high'): 178,
#  ('q117=Missing', 'q138=Missing', 'q139=Very high'): 179,
#  ('q112=Missing', 'q117=Missing', 'q139=Very high'): 196,
#  ('q139=Very high', 'q7=Minor'): 245,
#  ('q111=Minor', 'q139=Very high', 'q7=Minor'): 207,
#  ('q139=Very high', 'q141=Minor'): 245,
#  ('q111=Minor', 'q139=Very high', 'q141=Minor'): 177,
#  ('q139=Very high', 'q3=Very high'): 247,
#  ('q112=Missing', 'q139=Very high', 'q3=Very high'): 180,
#  ('q112=Missing', 'q132=Minor', 'q139=Very high'): 178,
#  ('q132=Minor', 'q138=Missing', 'q139=Very high'): 181,
#  ('q135=Missing', 'q136=Missing', 'q139=Very high'): 200,
#  ('q115=Missing', 'q135=Missing', 'q136=Missing', 'q139=Very high'): 200,
#  ('q114=Missing', 'q135=Missing', 'q136=Missing', 'q139=Very high'): 200,
#  ('q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q139=Very high'): 200,
#  ('q115=Missing', 'q136=Missing', 'q139=Very high'): 215,
#  ('q112=Missing', 'q115=Missing', 'q136=Missing', 'q139=Very high'): 178,
#  ('q115=Missing', 'q136=Missing', 'q138=Missing', 'q139=Very high'): 184,
#  ('q114=Missing', 'q115=Missing', 'q136=Missing', 'q139=Very high'): 215,
#  ('q112=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing',
#   'q139=Very high'): 178,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q139=Very high'): 178,
#  ('q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing',
#   'q139=Very high'): 184,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing',
#   'q139=Very high'): 178,
#  ('q112=Missing', 'q136=Missing', 'q139=Very high'): 224,
#  ('q112=Missing', 'q136=Missing', 'q138=Missing', 'q139=Very high'): 224,
#  ('q112=Missing', 'q114=Missing', 'q136=Missing', 'q139=Very high'): 224,
#  ('q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing',
#   'q139=Very high'): 224,
#  ('q136=Missing', 'q138=Missing', 'q139=Very high'): 230,
#  ('q114=Missing', 'q136=Missing', 'q138=Missing', 'q139=Very high'): 230,
#  ('q114=Missing', 'q136=Missing', 'q139=Very high'): 273,
#  ('q114=Missing', 'q135=Missing', 'q139=Very high'): 203,
#  ('q114=Missing', 'q115=Missing', 'q135=Missing', 'q139=Very high'): 203,
#  ('q112=Missing', 'q135=Missing', 'q139=Very high'): 211,
#  ('q112=Missing', 'q135=Missing', 'q138=Missing', 'q139=Very high'): 208,
#  ('q112=Missing', 'q115=Missing', 'q135=Missing', 'q139=Very high'): 211,
#  ('q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing',
#   'q139=Very high'): 208,
#  ('q135=Missing', 'q138=Missing', 'q139=Very high'): 219,
#  ('q115=Missing', 'q135=Missing', 'q138=Missing', 'q139=Very high'): 219,
#  ('q115=Missing', 'q135=Missing', 'q139=Very high'): 275,
#  ('q111=Minor', 'q114=Missing', 'q139=Very high'): 188,
#  ('q111=Minor', 'q138=Missing', 'q139=Very high'): 194,
#  ('q111=Minor', 'q112=Missing', 'q138=Missing', 'q139=Very high'): 188,
#  ('q111=Minor', 'q115=Missing', 'q139=Very high'): 195,
#  ('q111=Minor', 'q112=Missing', 'q139=Very high'): 202,
#  ('q114=Missing', 'q115=Missing', 'q138=Missing', 'q139=Very high'): 184,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing',
#   'q139=Very high'): 178,
#  ('q112=Missing', 'q114=Missing', 'q138=Missing', 'q139=Very high'): 224,
#  ('q114=Missing', 'q115=Missing', 'q139=Very high'): 237,
#  ('q112=Missing', 'q114=Missing', 'q115=Missing', 'q139=Very high'): 200,
#  ('q112=Missing', 'q114=Missing', 'q139=Very high'): 246,
#  ('q115=Missing', 'q138=Missing', 'q139=Very high'): 234,
#  ('q112=Missing', 'q115=Missing', 'q138=Missing', 'q139=Very high'): 223,
#  ('q112=Missing', 'q138=Missing', 'q139=Very high'): 293,
#  ('q115=Missing', 'q139=Very high'): 309,
#  ('q112=Missing', 'q115=Missing', 'q139=Very high'): 245,
#  ('q112=Missing', 'q139=Very high'): 315,
#  ('q133=Missing', 'q3=Very high'): 185,
#  ('q117=Missing', 'q133=Missing', 'q3=Very high'): 185,
#  ('q132=Minor', 'q3=Very high'): 191,
#  ('q111=Minor', 'q3=Very high'): 220,
#  ('q111=Minor', 'q3=Very high', 'q7=Minor'): 181,
#  ('5: Significant change, immediately', 'q3=Very high'): 227,
#  ('5: Significant change, immediately', 'q138=Missing', 'q3=Very high'): 178,
#  ('5: Significant change, immediately', 'q112=Missing', 'q3=Very high'): 178,
#  ('5: Significant change, immediately',
#   'q112=Missing',
#   'q138=Missing',
#   'q3=Very high'): 178,
#  ('q112=Missing', 'q117=Missing', 'q3=Very high'): 182,
#  ('q115=Missing', 'q117=Missing', 'q3=Very high'): 184,
#  ('q138=Missing', 'q3=Very high', 'q7=Minor'): 189,
#  ('q112=Missing', 'q138=Missing', 'q3=Very high', 'q7=Minor'): 177,
#  ('q112=Missing', 'q3=Very high', 'q7=Minor'): 191,
#  ('q114=Missing', 'q135=Missing', 'q3=Very high'): 182,
#  ('q114=Missing', 'q135=Missing', 'q136=Missing', 'q3=Very high'): 182,
#  ('q114=Missing', 'q115=Missing', 'q135=Missing', 'q3=Very high'): 182,
#  ('q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q3=Very high'): 182,
#  ('q135=Missing', 'q136=Missing', 'q3=Very high'): 188,
#  ('q115=Missing', 'q135=Missing', 'q136=Missing', 'q3=Very high'): 188,
#  ('q112=Missing', 'q135=Missing', 'q3=Very high'): 208,
#  ('q112=Missing', 'q135=Missing', 'q138=Missing', 'q3=Very high'): 208,
#  ('q112=Missing', 'q115=Missing', 'q135=Missing', 'q3=Very high'): 208,
#  ('q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing',
#   'q3=Very high'): 208,
#  ('q135=Missing', 'q138=Missing', 'q3=Very high'): 214,
#  ('q115=Missing', 'q135=Missing', 'q138=Missing', 'q3=Very high'): 214,
#  ('q115=Missing', 'q135=Missing', 'q3=Very high'): 268,
#  ('q115=Missing', 'q136=Missing', 'q3=Very high'): 206,
#  ('q114=Missing', 'q115=Missing', 'q136=Missing', 'q3=Very high'): 194,
#  ('q112=Missing', 'q136=Missing', 'q3=Very high'): 216,
#  ('q112=Missing', 'q136=Missing', 'q138=Missing', 'q3=Very high'): 216,
#  ('q112=Missing', 'q114=Missing', 'q136=Missing', 'q3=Very high'): 216,
#  ('q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing',
#   'q3=Very high'): 216,
#  ('q136=Missing', 'q138=Missing', 'q3=Very high'): 228,
#  ('q114=Missing', 'q136=Missing', 'q138=Missing', 'q3=Very high'): 216,
#  ('q114=Missing', 'q136=Missing', 'q3=Very high'): 260,
#  ('q114=Missing', 'q115=Missing', 'q3=Very high'): 213,
#  ('q114=Missing', 'q138=Missing', 'q3=Very high'): 216,
#  ('q112=Missing', 'q114=Missing', 'q138=Missing', 'q3=Very high'): 216,
#  ('q112=Missing', 'q114=Missing', 'q3=Very high'): 235,
#  ('q115=Missing', 'q138=Missing', 'q3=Very high'): 232,
#  ('q112=Missing', 'q115=Missing', 'q138=Missing', 'q3=Very high'): 220,
#  ('q112=Missing', 'q115=Missing', 'q3=Very high'): 239,
#  ('q138=Missing', 'q3=Very high'): 328,
#  ('q112=Missing', 'q138=Missing', 'q3=Very high'): 316,
#  ('q112=Missing', 'q3=Very high'): 335,
#  ('q132=Minor', 'q138=Minor'): 177,
#  ('q138=Minor', 'q141=Missing'): 185,
#  ('q138=Minor', 'q141=Minor'): 186,
#  ('q138=Minor', 'q7=Minor'): 187,
#  ('q138=Minor', 'q3=High'): 194,
#  ('q132=Missing', 'q138=Minor'): 195,
#  ('q135=Missing', 'q138=Minor'): 214,
#  ('q115=Missing', 'q135=Missing', 'q138=Minor'): 211,
#  ('q114=Missing', 'q138=Minor'): 219,
#  ('q114=Missing', 'q115=Missing', 'q138=Minor'): 193,
#  ('q117=Missing', 'q138=Minor'): 224,
#  ('q115=Missing', 'q117=Missing', 'q138=Minor'): 216,
#  ('q115=Missing', 'q138=Minor'): 306,
#  ('Democratic space', 'q139=High'): 180,
#  ('Democratic space', 'q111=Minor'): 188,
#  ('Democratic space', 'q118=Missing'): 188,
#  ('Democratic space', 'q109=Missing'): 210,
#  ('Democratic space', 'q109=Missing', 'q115=Missing'): 179,
#  ('Democratic space', 'q132=Missing'): 220,
#  ('Democratic space', 'q115=Missing', 'q132=Missing'): 191,
#  ('Democratic space', 'q114=Missing', 'q133=Missing'): 177,
#  ('Democratic space', 'q114=Missing', 'q117=Missing', 'q133=Missing'): 177,
#  ('Democratic space', 'q112=Missing', 'q133=Missing'): 182,
#  ('Democratic space', 'q112=Missing', 'q117=Missing', 'q133=Missing'): 182,
#  ('Democratic space', 'q133=Missing', 'q138=Missing'): 184,
#  ('Democratic space', 'q117=Missing', 'q133=Missing', 'q138=Missing'): 184,
#  ('Democratic space', 'q115=Missing', 'q133=Missing'): 201,
#  ('Democratic space', 'q115=Missing', 'q133=Missing', 'q135=Missing'): 201,
#  ('Democratic space', 'q115=Missing', 'q117=Missing', 'q133=Missing'): 201,
#  ('Democratic space',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 201,
#  ('Democratic space', 'q133=Missing', 'q135=Missing'): 202,
#  ('Democratic space', 'q117=Missing', 'q133=Missing', 'q135=Missing'): 202,
#  ('Democratic space', 'q117=Missing', 'q133=Missing'): 221,
#  ('Democratic space', 'q117=Missing', 'q135=Missing'): 204,
#  ('Democratic space', 'q115=Missing', 'q117=Missing', 'q135=Missing'): 203,
#  ('Democratic space', 'q117=Missing', 'q136=Missing', 'q138=Missing'): 181,
#  ('Democratic space', 'q115=Missing', 'q117=Missing', 'q136=Missing'): 187,
#  ('Democratic space',
#   'q114=Missing',
#   'q115=Missing',
#   'q117=Missing',
#   'q136=Missing'): 178,
#  ('Democratic space', 'q114=Missing', 'q117=Missing', 'q136=Missing'): 195,
#  ('Democratic space', 'q115=Missing', 'q117=Missing', 'q138=Missing'): 196,
#  ('Democratic space',
#   'q112=Missing',
#   'q115=Missing',
#   'q117=Missing',
#   'q138=Missing'): 183,
#  ('Democratic space', 'q112=Missing', 'q117=Missing', 'q138=Missing'): 202,
#  ('Democratic space', 'q112=Missing', 'q114=Missing', 'q117=Missing'): 191,
#  ('Democratic space', 'q114=Missing', 'q115=Missing', 'q117=Missing'): 200,
#  ('Democratic space', 'q112=Missing', 'q117=Missing'): 222,
#  ('Democratic space', 'q112=Missing', 'q115=Missing', 'q117=Missing'): 203,
#  ('Democratic space', 'q115=Missing', 'q117=Missing'): 246,
#  ('Democratic space', 'q112=Missing', 'q135=Missing', 'q136=Missing'): 204,
#  ('Democratic space',
#   'q112=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 204,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing'): 204,
#  ('Democratic space',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 203,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 204,
#  ('Democratic space',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 203,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 203,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 203,
#  ('Democratic space',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 208,
#  ('Democratic space',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 207,
#  ('Democratic space',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 210,
#  ('Democratic space', 'q114=Missing', 'q135=Missing', 'q136=Missing'): 247,
#  ('Democratic space',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 246,
#  ('Democratic space', 'q115=Missing', 'q135=Missing', 'q136=Missing'): 249,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q138=Missing'): 206,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 205,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 211,
#  ('Democratic space', 'q112=Missing', 'q135=Missing', 'q138=Missing'): 248,
#  ('Democratic space',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 247,
#  ('Democratic space', 'q112=Missing', 'q115=Missing', 'q135=Missing'): 253,
#  ('Democratic space', 'q114=Missing', 'q135=Missing', 'q138=Missing'): 210,
#  ('Democratic space',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 209,
#  ('Democratic space', 'q114=Missing', 'q115=Missing', 'q135=Missing'): 254,
#  ('Democratic space', 'q135=Missing', 'q138=Missing'): 256,
#  ('Democratic space', 'q115=Missing', 'q135=Missing', 'q138=Missing'): 255,
#  ('Democratic space', 'q115=Missing', 'q135=Missing'): 319,
#  ('Democratic space', 'q112=Missing', 'q136=Missing'): 261,
#  ('Democratic space', 'q112=Missing', 'q136=Missing', 'q138=Missing'): 261,
#  ('Democratic space', 'q112=Missing', 'q115=Missing', 'q136=Missing'): 224,
#  ('Democratic space', 'q112=Missing', 'q114=Missing', 'q136=Missing'): 261,
#  ('Democratic space',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 224,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 261,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 224,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 224,
#  ('Democratic space', 'q115=Missing', 'q136=Missing', 'q138=Missing'): 237,
#  ('Democratic space',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 228,
#  ('Democratic space', 'q114=Missing', 'q136=Missing', 'q138=Missing'): 265,
#  ('Democratic space', 'q115=Missing', 'q136=Missing'): 276,
#  ('Democratic space', 'q114=Missing', 'q115=Missing', 'q136=Missing'): 267,
#  ('Democratic space', 'q114=Missing', 'q136=Missing'): 318,
#  ('Democratic space', 'q114=Missing', 'q115=Missing', 'q138=Missing'): 231,
#  ('Democratic space',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 227,
#  ('Democratic space', 'q112=Missing', 'q114=Missing', 'q138=Missing'): 264,
#  ('Democratic space', 'q115=Missing', 'q138=Missing'): 283,
#  ('Democratic space', 'q112=Missing', 'q115=Missing', 'q138=Missing'): 269,
#  ('Democratic space', 'q112=Missing', 'q138=Missing'): 324,
#  ('Democratic space', 'q112=Missing', 'q114=Missing'): 286,
#  ('Democratic space', 'q112=Missing', 'q114=Missing', 'q115=Missing'): 247,
#  ('Democratic space', 'q114=Missing', 'q115=Missing'): 290,
#  ('Democratic space', 'q112=Missing'): 346,
#  ('Democratic space', 'q112=Missing', 'q115=Missing'): 289,
#  ('Democratic space', 'q115=Missing'): 362,
#  ('q111=Minor', 'q133=Very high'): 179,
#  ('q111=Missing', 'q133=Very high'): 183,
#  ('q133=Very high', 'q139=Missing'): 184,
#  ('q109=Missing', 'q133=Very high'): 192,
#  ('q133=Very high', 'q141=Missing'): 212,
#  ('q133=Very high', 'q135=Minor'): 221,
#  ('q132=Missing', 'q133=Very high', 'q138=Missing'): 178,
#  ('q118=Missing', 'q132=Missing', 'q133=Very high'): 234,
#  ('q117=Minor', 'q133=Very high'): 246,
#  ('q115=Missing', 'q133=Very high'): 262,
#  ('q114=Missing', 'q133=Very high', 'q138=Missing'): 200,
#  ('q112=Missing', 'q114=Missing', 'q133=Very high', 'q138=Missing'): 191,
#  ('q114=Missing', 'q133=Very high', 'q136=Missing', 'q138=Missing'): 200,
#  ('q112=Missing',
#   'q114=Missing',
#   'q133=Very high',
#   'q136=Missing',
#   'q138=Missing'): 191,
#  ('q112=Missing', 'q114=Missing', 'q133=Very high'): 202,
#  ('q112=Missing', 'q114=Missing', 'q133=Very high', 'q136=Missing'): 191,
#  ('q114=Missing', 'q133=Very high', 'q136=Missing'): 252,
#  ('q118=Missing', 'q133=Very high'): 266,
#  ('q118=Missing', 'q133=Very high', 'q138=Missing'): 181,
#  ('5: Significant change, immediately', 'q133=Very high'): 268,
#  ('5: Significant change, immediately', 'q133=Very high', 'q138=Missing'): 181,
#  ('q133=Very high', 'q136=Missing'): 273,
#  ('q112=Missing', 'q133=Very high', 'q136=Missing'): 191,
#  ('q133=Very high', 'q136=Missing', 'q138=Missing'): 221,
#  ('q112=Missing', 'q133=Very high', 'q136=Missing', 'q138=Missing'): 191,
#  ('q112=Missing', 'q133=Very high'): 287,
#  ('q112=Missing', 'q133=Very high', 'q138=Missing'): 276,
#  ('q133=Very high', 'q138=Missing'): 306,
#  ('Political stability', 'q139=Missing'): 180,
#  ('Political stability', 'q7=Minor'): 186,
#  ('Political stability', 'q3=High'): 195,
#  ('Political stability', 'q111=Missing'): 196,
#  ('Political stability', 'q133=Missing', 'q138=Missing'): 177,
#  ('Political stability', 'q115=Missing', 'q133=Missing'): 188,
#  ('Political stability', 'q115=Missing', 'q133=Missing', 'q135=Missing'): 188,
#  ('Political stability', 'q115=Missing', 'q117=Missing', 'q133=Missing'): 188,
#  ('Political stability',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 188,
#  ('Political stability', 'q133=Missing', 'q135=Missing'): 190,
#  ('Political stability', 'q117=Missing', 'q133=Missing', 'q135=Missing'): 188,
#  ('Political stability', 'q117=Missing', 'q133=Missing'): 219,
#  ('Political stability', 'q7=Moderate'): 226,
#  ('Political stability', 'q115=Missing', 'q141=Missing'): 178,
#  ('Political stability', 'q109=Missing', 'q141=Missing'): 198,
#  ('Political stability', 'q109=Missing', 'q138=Missing'): 177,
#  ('Political stability', 'q109=Missing', 'q112=Missing'): 179,
#  ('Political stability', 'q109=Missing', 'q115=Missing'): 185,
#  ('Political stability', 'q114=Missing', 'q118=Missing'): 180,
#  ('Political stability', 'q112=Missing', 'q118=Missing', 'q138=Missing'): 181,
#  ('Political stability', 'q118=Missing', 'q132=Missing', 'q138=Missing'): 181,
#  ('Political stability', 'q112=Missing', 'q118=Missing'): 194,
#  ('Political stability', 'q112=Missing', 'q118=Missing', 'q132=Missing'): 183,
#  ('Political stability', 'q115=Missing', 'q118=Missing'): 200,
#  ('Political stability', 'q115=Missing', 'q118=Missing', 'q132=Missing'): 188,
#  ('Political stability', 'q118=Missing', 'q132=Missing'): 238,
#  ('Political stability', 'q132=Missing', 'q135=Missing'): 183,
#  ('Political stability', 'q115=Missing', 'q132=Missing', 'q135=Missing'): 181,
#  ('Political stability', 'q132=Missing', 'q136=Missing'): 189,
#  ('Political stability', 'q114=Missing', 'q132=Missing', 'q136=Missing'): 179,
#  ('Political stability', 'q114=Missing', 'q132=Missing'): 197,
#  ('Political stability', 'q132=Missing', 'q138=Missing'): 207,
#  ('Political stability', 'q112=Missing', 'q132=Missing', 'q138=Missing'): 195,
#  ('Political stability', 'q112=Missing', 'q132=Missing'): 212,
#  ('Political stability', 'q112=Missing', 'q115=Missing', 'q132=Missing'): 177,
#  ('Political stability', 'q115=Missing', 'q132=Missing'): 224,
#  ('Political stability', 'q117=Missing', 'q135=Missing'): 191,
#  ('Political stability', 'q115=Missing', 'q117=Missing', 'q135=Missing'): 191,
#  ('Political stability', 'q117=Missing', 'q136=Missing'): 197,
#  ('Political stability', 'q114=Missing', 'q117=Missing', 'q136=Missing'): 185,
#  ('Political stability', 'q112=Missing', 'q114=Missing', 'q117=Missing'): 178,
#  ('Political stability', 'q114=Missing', 'q115=Missing', 'q117=Missing'): 181,
#  ('Political stability', 'q115=Missing', 'q117=Missing', 'q138=Missing'): 189,
#  ('Political stability', 'q112=Missing', 'q117=Missing', 'q138=Missing'): 197,
#  ('Political stability', 'q112=Missing', 'q117=Missing'): 216,
#  ('Political stability', 'q112=Missing', 'q115=Missing', 'q117=Missing'): 192,
#  ('Political stability', 'q115=Missing', 'q117=Missing'): 244,
#  ('Political stability', 'q112=Missing', 'q135=Missing', 'q136=Missing'): 185,
#  ('Political stability',
#   'q112=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 185,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing'): 185,
#  ('Political stability',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 183,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 185,
#  ('Political stability',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 183,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 183,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 183,
#  ('Political stability',
#   'q114=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 189,
#  ('Political stability',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 187,
#  ('Political stability',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 194,
#  ('Political stability', 'q114=Missing', 'q135=Missing', 'q136=Missing'): 224,
#  ('Political stability',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q136=Missing'): 222,
#  ('Political stability', 'q115=Missing', 'q135=Missing', 'q136=Missing'): 229,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q135=Missing',
#   'q138=Missing'): 186,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 184,
#  ('Political stability',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 188,
#  ('Political stability', 'q112=Missing', 'q114=Missing', 'q135=Missing'): 195,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q135=Missing'): 192,
#  ('Political stability', 'q114=Missing', 'q115=Missing', 'q135=Missing'): 231,
#  ('Political stability', 'q112=Missing', 'q135=Missing', 'q138=Missing'): 238,
#  ('Political stability',
#   'q112=Missing',
#   'q115=Missing',
#   'q135=Missing',
#   'q138=Missing'): 236,
#  ('Political stability', 'q112=Missing', 'q115=Missing', 'q135=Missing'): 244,
#  ('Political stability', 'q135=Missing', 'q138=Missing'): 250,
#  ('Political stability', 'q115=Missing', 'q135=Missing', 'q138=Missing'): 248,
#  ('Political stability', 'q115=Missing', 'q135=Missing'): 316,
#  ('Political stability', 'q112=Missing', 'q136=Missing'): 256,
#  ('Political stability', 'q112=Missing', 'q115=Missing', 'q136=Missing'): 211,
#  ('Political stability', 'q112=Missing', 'q136=Missing', 'q138=Missing'): 256,
#  ('Political stability', 'q112=Missing', 'q114=Missing', 'q136=Missing'): 256,
#  ('Political stability',
#   'q112=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 211,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing'): 211,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q136=Missing',
#   'q138=Missing'): 256,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 211,
#  ('Political stability', 'q115=Missing', 'q136=Missing', 'q138=Missing'): 227,
#  ('Political stability',
#   'q114=Missing',
#   'q115=Missing',
#   'q136=Missing',
#   'q138=Missing'): 215,
#  ('Political stability', 'q114=Missing', 'q115=Missing', 'q136=Missing'): 250,
#  ('Political stability', 'q136=Missing', 'q138=Missing'): 272,
#  ('Political stability', 'q114=Missing', 'q136=Missing', 'q138=Missing'): 260,
#  ('Political stability', 'q114=Missing', 'q136=Missing'): 312,
#  ('Political stability', 'q114=Missing', 'q115=Missing', 'q138=Missing'): 217,
#  ('Political stability',
#   'q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q138=Missing'): 213,
#  ('Political stability', 'q112=Missing', 'q114=Missing', 'q138=Missing'): 258,
#  ('Political stability', 'q114=Missing', 'q115=Missing'): 271,
#  ('Political stability', 'q112=Missing', 'q114=Missing', 'q115=Missing'): 232,
#  ('Political stability', 'q112=Missing', 'q114=Missing'): 279,
#  ('Political stability', 'q115=Missing', 'q138=Missing'): 282,
#  ('Political stability', 'q112=Missing', 'q115=Missing', 'q138=Missing'): 265,
#  ('Political stability', 'q112=Missing', 'q138=Missing'): 332,
#  ('Political stability', 'q112=Missing'): 353,
#  ('Political stability', 'q112=Missing', 'q115=Missing'): 284,
#  ('Political stability', 'q115=Missing'): 369,
#  ('5: Significant change, immediately', 'q112=Moderate'): 178,
#  ('q112=Moderate', 'q141=Missing'): 180,
#  ('q112=Moderate', 'q132=Missing'): 182,
#  ('q112=Moderate', 'q114=Missing'): 185,
#  ('q112=Moderate', 'q114=Missing', 'q136=Missing'): 185,
#  ('q112=Moderate', 'q114=Moderate'): 187,
#  ('q112=Moderate', 'q141=Minor'): 197,
#  ('q111=Moderate', 'q112=Moderate'): 214,
#  ('q112=Moderate', 'q135=Missing'): 216,
#  ('q112=Moderate', 'q115=Missing', 'q135=Missing'): 216,
#  ('q112=Moderate', 'q138=Moderate'): 233,
#  ('q112=Moderate', 'q7=Moderate'): 237,
#  ('q112=Moderate', 'q136=Missing'): 239,
#  ('q112=Moderate', 'q115=Missing'): 265,
#  ('q115=High', 'q7=Moderate'): 180,
#  ('q115=High', 'q141=Missing'): 182,
#  ('5: Significant change, immediately', 'q115=High'): 184,
#  ('q115=High', 'q135=Moderate'): 191,
#  ('q115=High', 'q139=High'): 194,
#  ('q115=High', 'q117=Minor'): 196,
#  ('q115=High', 'q132=Minor'): 196,
#  ('q111=Moderate', 'q115=High'): 208,
#  ('q115=High', 'q141=Minor'): 209,
#  ('q115=High', 'q3=High'): 215,
#  ('q115=High', 'q136=Missing'): 237,
#  ('q114=Missing', 'q115=High', 'q136=Missing'): 237,
#  ('q115=High', 'q133=High'): 238,
#  ('q114=Missing', 'q115=High'): 240,
#  ('q115=High', 'q135=Minor'): 281,
#  ('q115=High', 'q135=Minor', 'q138=Missing'): 177,
#  ('q112=Missing', 'q115=High'): 287,
#  ('q112=Missing', 'q115=High', 'q138=Missing'): 284,
#  ('q115=High', 'q138=Missing'): 292,
#  ('q133=Missing', 'q136=Moderate'): 179,
#  ('q114=Moderate', 'q136=Moderate'): 184,
#  ('q109=Moderate', 'q136=Moderate'): 186,
#  ('q111=Missing', 'q136=Moderate'): 195,
#  ('q136=Moderate', 'q139=Missing'): 197,
#  ('q136=Moderate', 'q138=Missing'): 201,
#  ('q112=Missing', 'q136=Moderate', 'q138=Missing'): 193,
#  ('q136=Moderate', 'q7=Moderate'): 213,
#  ('q109=Missing', 'q136=Moderate'): 218,
#  ('q109=Missing', 'q136=Moderate', 'q141=Missing'): 191,
#  ('q136=Moderate', 'q141=Missing'): 228,
#  ('q117=Missing', 'q136=Moderate'): 230,
#  ('q115=Missing', 'q117=Missing', 'q136=Moderate'): 203,
#  ('q135=Missing', 'q136=Moderate'): 237,
#  ('q115=Missing', 'q135=Missing', 'q136=Moderate'): 227,
#  ('q132=Missing', 'q136=Moderate'): 251,
#  ('q118=Missing', 'q132=Missing', 'q136=Moderate'): 233,
#  ('q118=Missing', 'q136=Moderate'): 264,
#  ('q115=Missing', 'q136=Moderate'): 288,
#  ('q112=Missing', 'q115=Missing', 'q136=Moderate'): 191,
#  ('q112=Missing', 'q136=Moderate'): 290,
#  ('q136=High', 'q139=High'): 181,
#  ('q118=High', 'q136=High'): 181,
#  ('q136=High', 'q139=Missing'): 181,
#  ('q109=Missing', 'q136=High'): 183,
#  ('q133=High', 'q136=High'): 183,
#  ('q136=High', 'q3=High'): 184,
#  ('q111=Moderate', 'q136=High'): 187,
#  ('q136=High', 'q138=Missing'): 193,
#  ('q112=Missing', 'q136=High', 'q138=Missing'): 193,
#  ('q136=High', 'q7=Minor'): 193,
#  ('q109=High', 'q136=High'): 197,
#  ('q136=High', 'q141=Minor'): 198,
#  ('q118=Missing', 'q136=High'): 202,
#  ('q136=High', 'q141=Missing'): 220,
#  ('q114=Minor', 'q136=High'): 240,
#  ('q135=Missing', 'q136=High'): 245,
#  ('q115=Missing', 'q135=Missing', 'q136=High'): 245,
#  ('5: Significant change, immediately', 'q136=High'): 248,
#  ('q112=Missing', 'q132=Missing', 'q136=High'): 182,
#  ('q117=Missing', 'q132=Missing', 'q136=High'): 186,
#  ('q115=Missing', 'q132=Missing', 'q136=High'): 196,
#  ('q112=Missing', 'q117=Missing', 'q136=High'): 179,
#  ('q115=Missing', 'q117=Missing', 'q136=High'): 232,
#  ('q112=Missing', 'q136=High'): 290,
#  ('q112=Missing', 'q115=Missing', 'q136=High'): 203,
#  ('q115=Missing', 'q136=High'): 329,
#  ('q114=Moderate', 'q117=Missing'): 180,
#  ('q109=High', 'q114=Moderate'): 181,
#  ('q114=Moderate', 'q135=Moderate'): 182,
#  ('q112=Missing', 'q114=Moderate'): 196,
#  ('q112=Missing', 'q114=Moderate', 'q138=Missing'): 196,
#  ('q114=Moderate', 'q3=High'): 205,
#  ('q114=Moderate', 'q141=Missing'): 210,
#  ('q114=Moderate', 'q139=Missing'): 213,
#  ('q114=Moderate', 'q117=Moderate'): 214,
#  ('q114=Moderate', 'q118=Missing'): 227,
#  ('q114=Moderate', 'q118=Missing', 'q132=Missing'): 212,
#  ('q111=Moderate', 'q114=Moderate'): 239,
#  ('q114=Moderate', 'q138=Missing'): 240,
#  ('q114=Moderate', 'q115=Missing', 'q138=Missing'): 181,
#  ('q114=Moderate', 'q132=Missing'): 241,
#  ('q114=Moderate', 'q115=Missing', 'q132=Missing'): 182,
#  ('q114=Moderate', 'q7=Moderate'): 248,
#  ('q114=Moderate', 'q135=Missing'): 271,
#  ('q114=Moderate', 'q115=Missing', 'q135=Missing'): 271,
#  ('q114=Moderate', 'q115=Missing'): 304,
#  ('5: Significant change, immediately', 'q135=Moderate'): 186,
#  ('q135=Moderate', 'q3=High'): 187,
#  ('q111=Moderate', 'q135=Moderate'): 197,
#  ('q135=Moderate', 'q136=Missing'): 214,
#  ('q114=Missing', 'q135=Moderate', 'q136=Missing'): 196,
#  ('q117=Missing', 'q135=Moderate'): 219,
#  ('q112=Missing', 'q117=Missing', 'q135=Moderate'): 188,
#  ('q118=Missing', 'q135=Moderate'): 227,
#  ('q118=Missing', 'q132=Missing', 'q135=Moderate'): 198,
#  ('q135=Moderate', 'q141=Missing'): 231,
#  ('q109=Missing', 'q135=Moderate', 'q141=Missing'): 193,
#  ('q109=Missing', 'q135=Moderate'): 238,
#  ('q135=Moderate', 'q7=Moderate'): 247,
#  ('q132=Missing', 'q135=Moderate'): 256,
#  ('q112=Missing', 'q132=Missing', 'q135=Moderate'): 193,
#  ('q135=Moderate', 'q138=Missing'): 258,
#  ('q112=Missing', 'q135=Moderate', 'q138=Missing'): 240,
#  ('q133=High', 'q135=Moderate'): 264,
#  ('q114=Missing', 'q135=Moderate'): 275,
#  ('q112=Missing', 'q114=Missing', 'q135=Moderate'): 232,
#  ('q112=Missing', 'q135=Moderate'): 310,
#  ('4: Significant change, not urgent', 'q7=Moderate'): 178,
#  ('4: Significant change, not urgent', 'q139=Missing'): 179,
#  ('4: Significant change, not urgent', 'q111=Missing'): 207,
#  ('4: Significant change, not urgent', 'q3=Missing'): 212,
#  ('4: Significant change, not urgent', 'q3=Missing', 'q7=Missing'): 212,
#  ('4: Significant change, not urgent', 'q112=Missing', 'q3=Missing'): 178,
#  ('4: Significant change, not urgent',
#   'q112=Missing',
#   'q3=Missing',
#   'q7=Missing'): 178,
#  ('4: Significant change, not urgent', 'q7=Missing'): 216,
#  ('4: Significant change, not urgent', 'q112=Missing', 'q7=Missing'): 180,
#  ('4: Significant change, not urgent', 'q112=Missing', 'q141=Missing'): 183,
#  ('4: Significant change, not urgent', 'q109=Missing', 'q141=Missing'): 198,
#  ('4: Significant change, not urgent', 'q109=Missing'): 235,
#  ('4: Significant change, not urgent', 'q109=Missing', 'q112=Missing'): 192,
#  ('4: Significant change, not urgent', 'q114=Missing', 'q133=Missing'): 180,
#  ('4: Significant change, not urgent', 'q112=Missing', 'q133=Missing'): 200,
#  ('4: Significant change, not urgent',
#   'q112=Missing',
#   'q117=Missing',
#   'q133=Missing'): 187,
#  ('4: Significant change, not urgent', 'q115=Missing', 'q133=Missing'): 204,
#  ('4: Significant change, not urgent',
#   'q115=Missing',
#   'q133=Missing',
#   'q135=Missing'): 204,
#  ('4: Significant change, not urgent',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing'): 204,
#  ('4: Significant change, not urgent',
#   'q115=Missing',
#   'q117=Missing',
#   'q133=Missing',
#   'q135=Missing'): 204,
#  ('4: Significant change, not urgent', 'q133=Missing', 'q135=Missing'): 217,
# ...
#  ('q111=Moderate', 'q138=Moderate', 'q7=Moderate'): 178,
#  ('q138=Moderate', 'q141=Missing'): 267,
#  ('q111=Moderate', 'q138=Moderate'): 277,
#  ('q135=Missing', 'q138=Moderate'): 295,
#  ('q115=Missing', 'q135=Missing', 'q138=Moderate'): 288,
#  ('q115=Missing', 'q118=Missing', 'q138=Moderate'): 177,
#  ('q114=Missing', 'q118=Missing', 'q138=Moderate'): 200,
#  ('q118=Missing', 'q132=Missing', 'q138=Moderate'): 254,
#  ('q114=Missing', 'q132=Missing', 'q138=Moderate'): 203,
#  ('q115=Missing', 'q132=Missing', 'q138=Moderate'): 215,
#  ('q114=Missing', 'q138=Moderate'): 341,
#  ('q114=Missing', 'q115=Missing', 'q138=Moderate'): 204,
#  ('q115=Missing', 'q138=Moderate'): 351,
#  ('q118=Moderate', 'q141=Minor'): 183,
#  ('q118=Moderate', 'q3=Missing'): 188,
#  ('q118=Moderate', 'q7=Missing'): 188,
#  ('q118=Moderate', 'q3=Missing', 'q7=Missing'): 188,
#  ('q111=Minor', 'q118=Moderate'): 204,
#  ('q109=Missing', 'q118=Moderate'): 210,
#  ('q109=Missing', 'q118=Moderate', 'q141=Missing'): 187,
#  ('q118=Moderate', 'q3=Moderate'): 214,
#  ('q109=Moderate', 'q118=Moderate'): 221,
#  ('q118=Moderate', 'q141=Missing'): 224,
#  ('q111=Moderate', 'q118=Moderate'): 226,
#  ('3: Minor change, immediately', 'q118=Moderate'): 233,
#  ('q118=Moderate', 'q132=Minor'): 243,
#  ('q114=Missing', 'q118=Moderate', 'q133=Missing'): 186,
#  ('q114=Missing', 'q118=Moderate', 'q133=Missing', 'q136=Missing'): 179,
#  ('q114=Missing', 'q117=Missing', 'q118=Moderate', 'q133=Missing'): 186,
#  ('q114=Missing',
#   'q117=Missing',
#   'q118=Moderate',
#   'q133=Missing',
#   'q136=Missing'): 179,
#  ('q118=Moderate', 'q133=Missing', 'q136=Missing'): 189,
#  ('q117=Missing', 'q118=Moderate', 'q133=Missing', 'q136=Missing'): 189,
#  ('q118=Moderate', 'q133=Missing', 'q135=Missing'): 219,
#  ('q117=Missing', 'q118=Moderate', 'q133=Missing', 'q135=Missing'): 219,
#  ('q115=Missing', 'q118=Moderate', 'q133=Missing'): 219,
#  ('q115=Missing', 'q118=Moderate', 'q133=Missing', 'q135=Missing'): 219,
#  ('q115=Missing', 'q117=Missing', 'q118=Moderate', 'q133=Missing'): 219,
#  ('q115=Missing',
#   'q117=Missing',
#   'q118=Moderate',
#   'q133=Missing',
#   'q135=Missing'): 219,
#  ('q117=Missing', 'q118=Moderate', 'q133=Missing'): 245,
#  ('q118=Moderate', 'q132=Moderate'): 252,
#  ('q118=Moderate', 'q132=Moderate', 'q135=Missing'): 179,
#  ('q115=Missing', 'q118=Moderate', 'q132=Moderate'): 179,
#  ('q115=Missing', 'q118=Moderate', 'q132=Moderate', 'q135=Missing'): 179,
#  ('q118=Moderate', 'q136=Missing', 'q139=Moderate'): 181,
#  ('q114=Missing', 'q118=Moderate', 'q136=Missing', 'q139=Moderate'): 177,
#  ('q114=Missing', 'q118=Moderate', 'q139=Moderate'): 184,
#  ('q118=Moderate', 'q7=Moderate'): 257,
#  ('q112=Missing', 'q117=Missing', 'q118=Moderate', 'q138=Missing'): 177,
#  ('q112=Missing', 'q115=Missing', 'q117=Missing', 'q118=Moderate'): 179,
#  ('q117=Missing', 'q118=Moderate', 'q138=Missing'): 201,
#  ('q115=Missing', 'q117=Missing', 'q118=Moderate', 'q136=Missing'): 185,
#  ('q114=Missing', 'q117=Missing', 'q118=Moderate', 'q136=Missing'): 202,
#  ('q117=Missing', 'q118=Moderate', 'q135=Missing'): 219,
#  ('q115=Missing', 'q117=Missing', 'q118=Moderate', 'q135=Missing'): 219,
#  ('q114=Missing', 'q117=Missing', 'q118=Moderate'): 228,
#  ('q114=Missing', 'q115=Missing', 'q117=Missing', 'q118=Moderate'): 195,
#  ('q115=Missing', 'q117=Missing', 'q118=Moderate'): 252,
#  ('q114=Missing', 'q118=Moderate', 'q135=Missing', 'q138=Missing'): 202,
#  ('q114=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 202,
#  ('q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q118=Moderate', 'q135=Missing', 'q136=Missing', 'q138=Missing'): 209,
#  ('q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 209,
#  ('q115=Missing', 'q118=Moderate', 'q135=Missing', 'q138=Missing'): 257,
#  ('q114=Missing', 'q118=Moderate', 'q135=Missing'): 273,
#  ('q114=Missing', 'q118=Moderate', 'q135=Missing', 'q136=Missing'): 266,
#  ('q114=Missing', 'q115=Missing', 'q118=Moderate', 'q135=Missing'): 273,
#  ('q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 266,
#  ('q118=Moderate', 'q135=Missing', 'q136=Missing'): 276,
#  ('q115=Missing', 'q118=Moderate', 'q135=Missing', 'q136=Missing'): 276,
#  ('q115=Missing', 'q118=Moderate', 'q135=Missing'): 378,
#  ('q112=Missing', 'q118=Moderate', 'q135=Missing', 'q136=Missing'): 199,
#  ('q112=Missing',
#   'q114=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 199,
#  ('q112=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q112=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 199,
#  ('q112=Missing',
#   'q114=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 199,
#  ('q112=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 199,
#  ('q112=Missing', 'q114=Missing', 'q118=Moderate', 'q135=Missing'): 206,
#  ('q112=Missing',
#   'q114=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 202,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing'): 206,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 202,
#  ('q112=Missing', 'q118=Moderate', 'q135=Missing', 'q138=Missing'): 247,
#  ('q112=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 247,
#  ('q112=Missing', 'q115=Missing', 'q118=Moderate', 'q135=Missing'): 251,
#  ('q112=Missing', 'q118=Moderate', 'q136=Missing'): 260,
#  ('q112=Missing', 'q115=Missing', 'q118=Moderate', 'q136=Missing'): 207,
#  ('q112=Missing', 'q114=Missing', 'q118=Moderate', 'q136=Missing'): 260,
#  ('q112=Missing', 'q118=Moderate', 'q136=Missing', 'q138=Missing'): 260,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q136=Missing'): 207,
#  ('q112=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 207,
#  ('q112=Missing',
#   'q114=Missing',
#   'q118=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 260,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 207,
#  ('q112=Missing', 'q114=Missing', 'q115=Missing', 'q118=Moderate'): 233,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q138=Missing'): 210,
#  ('q112=Missing', 'q115=Missing', 'q118=Moderate', 'q138=Missing'): 255,
#  ('q112=Missing', 'q114=Missing', 'q118=Moderate'): 286,
#  ('q112=Missing', 'q114=Missing', 'q118=Moderate', 'q138=Missing'): 263,
#  ('q112=Missing', 'q118=Moderate', 'q138=Missing'): 355,
#  ('q114=Missing', 'q115=Missing', 'q118=Moderate', 'q138=Missing'): 210,
#  ('q114=Missing',
#   'q115=Missing',
#   'q118=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 207,
#  ('q114=Missing', 'q118=Moderate', 'q136=Missing', 'q138=Missing'): 260,
#  ('q115=Missing', 'q118=Moderate', 'q138=Missing'): 271,
#  ('q115=Missing', 'q118=Moderate', 'q136=Missing', 'q138=Missing'): 223,
#  ('q118=Moderate', 'q136=Missing', 'q138=Missing'): 276,
#  ('q115=Missing', 'q118=Moderate', 'q136=Missing'): 290,
#  ('q114=Missing', 'q115=Missing', 'q118=Moderate', 'q136=Missing'): 274,
#  ('q114=Missing', 'q118=Moderate', 'q136=Missing'): 377,
#  ('q114=Missing', 'q118=Moderate'): 403,
#  ('q114=Missing', 'q115=Missing', 'q118=Moderate'): 300,
#  ('q115=Missing', 'q118=Moderate'): 411,
#  ('q133=Moderate', 'q139=Moderate'): 177,
#  ('q132=Minor', 'q133=Moderate'): 179,
#  ('q109=Moderate', 'q133=Moderate'): 187,
#  ('3: Minor change, immediately', 'q133=Moderate'): 204,
#  ('q111=Moderate', 'q133=Moderate'): 218,
#  ('q133=Moderate', 'q139=Missing'): 221,
#  ('q111=Missing', 'q133=Moderate', 'q139=Missing'): 200,
#  ('q133=Moderate', 'q3=Moderate'): 222,
#  ('q111=Missing', 'q133=Moderate'): 230,
#  ('q118=Missing', 'q132=Missing', 'q133=Moderate', 'q136=Missing'): 179,
#  ('q114=Missing', 'q132=Missing', 'q133=Moderate', 'q136=Missing'): 182,
#  ('q115=Missing', 'q132=Missing', 'q133=Moderate', 'q138=Missing'): 178,
#  ('q118=Missing', 'q132=Missing', 'q133=Moderate', 'q138=Missing'): 191,
#  ('q112=Missing',
#   'q118=Missing',
#   'q132=Missing',
#   'q133=Moderate',
#   'q138=Missing'): 183,
#  ('q112=Missing', 'q132=Missing', 'q133=Moderate', 'q138=Missing'): 195,
#  ('q112=Missing', 'q114=Missing', 'q132=Missing', 'q133=Moderate'): 185,
#  ('q114=Missing', 'q118=Missing', 'q132=Missing', 'q133=Moderate'): 185,
#  ('q114=Missing', 'q115=Missing', 'q132=Missing', 'q133=Moderate'): 201,
#  ('q112=Missing', 'q118=Missing', 'q132=Missing', 'q133=Moderate'): 191,
#  ('q112=Missing', 'q115=Missing', 'q132=Missing', 'q133=Moderate'): 200,
#  ('q115=Missing', 'q132=Missing', 'q133=Moderate'): 245,
#  ('q115=Missing', 'q118=Missing', 'q132=Missing', 'q133=Moderate'): 211,
#  ('q118=Missing', 'q132=Missing', 'q133=Moderate'): 253,
#  ('q118=Missing', 'q133=Moderate', 'q136=Missing', 'q138=Missing'): 179,
#  ('q115=Missing', 'q118=Missing', 'q133=Moderate', 'q136=Missing'): 181,
#  ('q114=Missing', 'q118=Missing', 'q133=Moderate', 'q136=Missing'): 201,
#  ('q114=Missing', 'q118=Missing', 'q133=Moderate', 'q138=Missing'): 177,
#  ('q115=Missing', 'q118=Missing', 'q133=Moderate', 'q138=Missing'): 182,
#  ('q112=Missing', 'q118=Missing', 'q133=Moderate', 'q138=Missing'): 210,
#  ('q114=Missing', 'q115=Missing', 'q118=Missing', 'q133=Moderate'): 187,
#  ('q112=Missing', 'q114=Missing', 'q118=Missing', 'q133=Moderate'): 190,
#  ('q112=Missing', 'q118=Missing', 'q133=Moderate'): 226,
#  ('q112=Missing', 'q115=Missing', 'q118=Missing', 'q133=Moderate'): 182,
#  ('q115=Missing', 'q118=Missing', 'q133=Moderate'): 227,
#  ('q109=Missing', 'q133=Moderate', 'q136=Missing'): 185,
#  ('q109=Missing', 'q114=Missing', 'q133=Moderate', 'q136=Missing'): 180,
#  ('q109=Missing', 'q114=Missing', 'q133=Moderate'): 190,
#  ('q109=Missing', 'q112=Missing', 'q133=Moderate'): 203,
#  ('q109=Missing', 'q112=Missing', 'q133=Moderate', 'q138=Missing'): 196,
#  ('q109=Missing', 'q112=Missing', 'q133=Moderate', 'q141=Missing'): 180,
#  ('q109=Missing',
#   'q112=Missing',
#   'q133=Moderate',
#   'q138=Missing',
#   'q141=Missing'): 180,
#  ('q109=Missing', 'q133=Moderate', 'q138=Missing'): 204,
#  ('q109=Missing', 'q133=Moderate', 'q138=Missing', 'q141=Missing'): 188,
#  ('q109=Missing', 'q115=Missing', 'q133=Moderate'): 206,
#  ('q109=Missing', 'q115=Missing', 'q133=Moderate', 'q141=Missing'): 183,
#  ('q109=Missing', 'q133=Moderate', 'q141=Missing'): 267,
#  ('q133=Moderate', 'q7=Moderate'): 291,
#  ('q115=Missing', 'q133=Moderate', 'q7=Moderate'): 201,
#  ('q133=Moderate', 'q136=Missing', 'q141=Missing'): 191,
#  ('q114=Missing', 'q133=Moderate', 'q136=Missing', 'q141=Missing'): 186,
#  ('q114=Missing', 'q133=Moderate', 'q141=Missing'): 192,
#  ('q112=Missing', 'q133=Moderate', 'q141=Missing'): 205,
#  ('q112=Missing', 'q133=Moderate', 'q138=Missing', 'q141=Missing'): 202,
#  ('q115=Missing', 'q133=Moderate', 'q141=Missing'): 208,
#  ('q133=Moderate', 'q138=Missing', 'q141=Missing'): 210,
#  ('q117=Moderate', 'q133=Moderate'): 305,
#  ('q117=Moderate', 'q133=Moderate', 'q135=Missing'): 201,
#  ('q115=Missing', 'q117=Moderate', 'q133=Moderate'): 201,
#  ('q115=Missing', 'q117=Moderate', 'q133=Moderate', 'q135=Missing'): 201,
#  ('q133=Moderate', 'q135=Missing', 'q136=Missing'): 234,
#  ('q112=Missing', 'q133=Moderate', 'q135=Missing', 'q136=Missing'): 189,
#  ('q133=Moderate', 'q135=Missing', 'q136=Missing', 'q138=Missing'): 192,
#  ('q115=Missing', 'q133=Moderate', 'q135=Missing', 'q136=Missing'): 234,
#  ('q112=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 189,
#  ('q112=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 189,
#  ('q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 192,
#  ('q112=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 189,
#  ('q114=Missing', 'q133=Moderate', 'q135=Missing'): 234,
#  ('q114=Missing', 'q133=Moderate', 'q135=Missing', 'q136=Missing'): 234,
#  ('q112=Missing', 'q114=Missing', 'q133=Moderate', 'q135=Missing'): 189,
#  ('q114=Missing', 'q133=Moderate', 'q135=Missing', 'q138=Missing'): 192,
#  ('q114=Missing', 'q115=Missing', 'q133=Moderate', 'q135=Missing'): 234,
#  ('q112=Missing',
#   'q114=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 189,
#  ('q114=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 192,
#  ('q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 234,
#  ('q112=Missing',
#   'q114=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 189,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing'): 189,
#  ('q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 192,
#  ('q112=Missing',
#   'q114=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 189,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing'): 189,
#  ('q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 192,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 189,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q136=Missing',
#   'q138=Missing'): 189,
#  ('q112=Missing', 'q133=Moderate', 'q135=Missing'): 241,
#  ('q112=Missing', 'q133=Moderate', 'q135=Missing', 'q138=Missing'): 241,
#  ('q112=Missing', 'q115=Missing', 'q133=Moderate', 'q135=Missing'): 241,
#  ('q112=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q135=Missing',
#   'q138=Missing'): 241,
#  ('q133=Moderate', 'q135=Missing', 'q138=Missing'): 244,
#  ('q115=Missing', 'q133=Moderate', 'q135=Missing', 'q138=Missing'): 244,
#  ('q115=Missing', 'q133=Moderate', 'q135=Missing'): 344,
#  ('q112=Missing', 'q115=Missing', 'q133=Moderate', 'q136=Missing'): 245,
#  ('q112=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 245,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q136=Missing'): 245,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 245,
#  ('q115=Missing', 'q133=Moderate', 'q136=Missing', 'q138=Missing'): 253,
#  ('q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 248,
#  ('q114=Missing', 'q115=Missing', 'q133=Moderate', 'q136=Missing'): 290,
#  ('q112=Missing', 'q133=Moderate', 'q136=Missing'): 296,
#  ('q112=Missing', 'q133=Moderate', 'q136=Missing', 'q138=Missing'): 296,
#  ('q112=Missing', 'q114=Missing', 'q133=Moderate', 'q136=Missing'): 296,
#  ('q112=Missing',
#   'q114=Missing',
#   'q133=Moderate',
#   'q136=Missing',
#   'q138=Missing'): 296,
#  ('q133=Moderate', 'q136=Missing', 'q138=Missing'): 304,
#  ('q114=Missing', 'q133=Moderate', 'q136=Missing', 'q138=Missing'): 299,
#  ('q114=Missing', 'q133=Moderate', 'q136=Missing'): 358,
#  ('q114=Missing', 'q115=Missing', 'q133=Moderate', 'q138=Missing'): 251,
#  ('q112=Missing',
#   'q114=Missing',
#   'q115=Missing',
#   'q133=Moderate',
#   'q138=Missing'): 248,
#  ('q112=Missing', 'q114=Missing', 'q133=Moderate', 'q138=Missing'): 299,
#  ('q115=Missing', 'q133=Moderate', 'q138=Missing'): 308,
#  ('q112=Missing', 'q115=Missing', 'q133=Moderate', 'q138=Missing'): 300,
#  ('q112=Missing', 'q133=Moderate', 'q138=Missing'): 378,
#  ('q114=Missing', 'q115=Missing', 'q133=Moderate'): 323,
#  ('q112=Missing', 'q114=Missing', 'q115=Missing', 'q133=Moderate'): 278,
#  ('q112=Missing', 'q114=Missing', 'q133=Moderate'): 337,
#  ('q112=Missing', 'q133=Moderate'): 416,
#  ('q112=Missing', 'q115=Missing', 'q133=Moderate'): 330,
#  ...}

# %% [markdown]
# Get relevant patterns
# Those that include the outcome and not all predictors are missing values

# %%
relevant_patterns = dict()

for k,v in patterns.items():
    items = set(k)
    
    predictors = set(k).difference(set(risks))
    flag = sum([1 if 'Missing' in a else 0 for a in k]) == 0
    
    if flag and len(set(k).intersection(set(risks))) > 0 and len(k) > 1:
        relevant_patterns[k] = v

# %% [markdown]
# Now we can print the relevant patterns. The pre-pended question ids should help you identify the questions that correlate to outcome with your given support threshold.

# %%
relevant_patterns
# Out:
# {('Democratic space', 'q139=High'): 180,
#  ('Democratic space', 'q111=Minor'): 188,
#  ('Political stability', 'q7=Minor'): 186,
#  ('Political stability', 'q3=High'): 195,
#  ('Political stability', 'q7=Moderate'): 226}
